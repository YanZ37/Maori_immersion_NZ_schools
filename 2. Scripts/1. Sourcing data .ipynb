# %% [markdown]
# #### **Step 1** Merge datasets

# %%
# --- Import libraries ---
import pandas as pd

# --- Load Excel file ---
file_path = r'C:\Users\sanch\Documents\CareerFoundry\Achievement 6\1. Data\student_rolls_1.xlsx'
excel_file = pd.ExcelFile(file_path)

# --- Combine all sheets into one DataFrame ---
all_data = []

for sheet in excel_file.sheet_names:
    # Read each year sheet, skipping metadata rows
    df = pd.read_excel(file_path, sheet_name=sheet, skiprows=3)
    
    # Add a Year column (convert to int)
    df["Year"] = int(sheet)
    
    # Append to list
    all_data.append(df)

# Concatenate all years
df_all = pd.concat(all_data, ignore_index=True)

# Move the "Year" column forward
key_cols = ["School ID", "School Name", "Year"]
df_all = df_all[key_cols + [col for col in df_all.columns if col not in key_cols]]

# Rename columns for clarity
df_all = df_all.rename(columns={"Total  ": "Total Roll"})
df_all = df_all.rename(columns={"Gender": "School Gender"})
df_all = df_all.rename(columns={"Type": "School Type"})
df_all = df_all.rename(columns={"Authority": "School Authority"})

# %%
# --- Save the merged dataset ---
df_all.to_csv("Merged_2010_2024.csv", index=False)

# %% [markdown]
# #### **Step 2** Data Preparation

# %%
# --- Inspect the descriptive statistics of the merged dataset ---
df_all.describe()
# Out:
#           School ID          Year        Decile    Total Roll         Māori  \
# count  38119.000000  38119.000000  33048.000000  38119.000000  38119.000000
# mean    2029.854430   2016.985467      6.755174    313.675333     74.729400
# std     1285.718181      4.327598     11.363063    371.165181     95.177185
# min        1.000000   2010.000000      1.000000      0.000000      0.000000
# 25%     1168.000000   2013.000000      3.000000     89.000000     18.000000
# 50%     1908.000000   2017.000000      5.000000    207.000000     44.000000
# 75%     2961.000000   2021.000000      8.000000    411.000000     97.000000
# max     6980.000000   2024.000000     99.000000   9164.000000   3128.000000
#
#             Pacific         Asian         MELAA         Other  \
# count  38119.000000  38119.000000  38119.000000  38119.000000
# mean      30.775519     39.641727      6.368688      2.912721
# std       80.216172     95.309272     13.120339     10.812378
# min        0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      1.000000      0.000000      0.000000
# 50%        6.000000      8.000000      1.000000      0.000000
# 75%       23.000000     34.000000      7.000000      2.000000
# max     1316.000000   1781.000000    226.000000    697.000000
#
#        European/ Pākehā  ...       Year 14       Year 15       Level 1  \
# count      38119.000000  ...  38119.000000  38119.000000  38119.000000
# mean         155.610404  ...      0.555550      0.443453      5.813925
# std          219.202934  ...     15.978815     13.357273     26.717629
# min            0.000000  ...      0.000000      0.000000      0.000000
# 25%           22.000000  ...      0.000000      0.000000      0.000000
# 50%           83.000000  ...      0.000000      0.000000      0.000000
# 75%          207.000000  ...      0.000000      0.000000      0.000000
# max         4700.000000  ...   1206.000000   1500.000000    461.000000
#
#             Level 2       Level 3      Level 4A      Level 4B       Level 5  \
# count  38119.000000  38119.000000  38119.000000  38119.000000  38119.000000
# mean       2.196175      3.109893      3.892599     13.010047     49.328078
# std       12.650362     19.359861     27.550723     52.877122    117.900132
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000     25.000000
# max      240.000000    631.000000    625.000000   1340.000000   1113.000000
#
#          Taha Māori          None
# count  38119.000000  38119.000000
# mean     132.307091     97.710538
# std      186.549361    321.183850
# min        0.000000    -19.000000
# 25%        0.000000      0.000000
# 50%       38.000000      0.000000
# 75%      211.000000      0.000000
# max     1561.000000   7735.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# ##### **Observation:**
# The "Decile" contains maximum values of 99.
# In the Ministry of Education School Rolls dataset, Decile values of 99 are not valid deciles.
# They are a missing-value code used internally by the Ministry.

# %%
# Identify missing values for df_all.csv
df_all.isnull().sum()
# Out:
# School ID                         0
# School Name                       0
# Year                              0
# Decile                         5071
# School Type                       0
#                               ...
# Level 5                           0
# Taha Māori                        0
# None                              0
# Takiwā                        33048
# Another Gender/ Not Stated    33048
# Length: 67, dtype: int64

# %% [markdown]
# ##### **Observation:**
# Missing values in "Decile" should be handled because they are relevant to the analysis. The missing values in "Takiwā" or "Another Gender/ Not Stated" will be ignored because these two columns will not be used for analysis.

# %% [markdown]
# #### **Step 3** Data Cleaning

# %%
import numpy as np

# 1) Replace '99' with NaN (MoE missing-code) if applicable
df_all["Decile"] = pd.to_numeric(df_all["Decile"], errors="coerce").replace(99, np.nan)

# %%
# 2) Identify rows with missing Decile
missing_rows = df_all[df_all["Decile"].isna()]

# %%
missing_rows
# Out:
#        School ID                         School Name  Year  Decile  \
# 50            52       Tyndale Park Christian School  2010     NaN
# 313          345            Pacific Christian School  2010     NaN
# 372          425     Odyssey House School (Auckland)  2010     NaN
# 384          453                      Kadimah School  2010     NaN
# 386          456           Pukekohe Christian School  2010     NaN
# ...          ...                                 ...   ...     ...
# 38114       6975                       Garin College  2024     NaN
# 38115       6976             Rototuna Primary School  2024     NaN
# 38116       6977  Hobsonville Point Secondary School  2024     NaN
# 38117       6978            Reremoana Primary School  2024     NaN
# 38118       6980                   Clearview Primary  2024     NaN
#
#                  School Type       School Authority School Gender  \
# 50     Composite (Year 1-15)    Private: Fully Reg.         Co-Ed
# 313             Full Primary    Private: Fully Reg.         Co-Ed
# 372    Secondary (Year 9-15)    Private: Fully Reg.         Co-Ed
# 384             Full Primary      State: Integrated         Co-Ed
# 386    Composite (Year 1-15)    Private: Fully Reg.         Co-Ed
# ...                      ...                    ...           ...
# 38114  Secondary (Year 9-15)      State: Integrated         Co-Ed
# 38115           Contributing  State: Not integrated         Co-Ed
# 38116  Secondary (Year 9-15)  State: Not integrated         Co-Ed
# 38117           Full Primary  State: Not integrated         Co-Ed
# 38118           Full Primary  State: Not integrated         Co-Ed
#
#         Regional Council                 Education Region  \
# 50       Auckland Region                         Auckland
# 313      Auckland Region                         Auckland
# 372      Auckland Region                         Auckland
# 384      Auckland Region                         Auckland
# 386      Auckland Region                         Auckland
# ...                  ...                              ...
# 38114      Nelson Region  Nelson, Marlborough, West Coast
# 38115     Waikato Region                          Waikato
# 38116    Auckland Region           Tāmaki Herenga Tāngata
# 38117    Auckland Region              Tāmaki Herenga Waka
# 38118  Canterbury Region   Canterbury and Chatham Islands
#
#       TA with Auckland Local Board  ...  Level 1 Level 2 Level 3  Level 4A  \
# 50                Auckland- Howick  ...        0       0       0         0
# 313      Auckland- Mangere-Otahuhu  ...        0       0       0         0
# 372                 Auckland- Whau  ...        0       0       0         0
# 384            Auckland- Waitemata  ...        0       0       0         0
# 386             Auckland- Franklin  ...        0       0       0         0
# ...                            ...  ...      ...     ...     ...       ...
# 38114                  Nelson City  ...        0       0       0         0
# 38115                Hamilton City  ...        0       0       0         0
# 38116      Auckland- Upper Harbour  ...        0       0       0         0
# 38117           Auckland- Manurewa  ...        0       0       0         0
# 38118              Selwyn District  ...        0       0       0         0
#
#        Level 4B  Level 5  Taha Māori  None         Takiwā  \
# 50            0        0           0   140            NaN
# 313           0        0           0   109            NaN
# 372           0        0           0    29            NaN
# 384           0        0         101     0            NaN
# 386           0        0           0   191            NaN
# ...         ...      ...         ...   ...            ...
# 38114        29      153           0   425   Te Tai Runga
# 38115         0        0         758     0  Te Tai Whenua
# 38116        50      104           0   653    Te Tai Raro
# 38117         0       85         319     0    Te Tai Raro
# 38118         0      133         681     0   Te Tai Runga
#
#        Another Gender/ Not Stated
# 50                            NaN
# 313                           NaN
# 372                           NaN
# 384                           NaN
# 386                           NaN
# ...                           ...
# 38114                           0
# 38115                           0
# 38116                          11
# 38117                           0
# 38118                           0
#
# [5533 rows x 67 columns]

# %%
# 3) For each School ID, check if any other year has a Decile
has_decile_elsewhere = (
    df_all
    .groupby("School ID")["Decile"]
    .apply(lambda s: s.notna().any())
    .rename("HasDecileInAnyYear")
    .reset_index()
)

# %%
# 4) Attach that flag back to the rows with missing Decile
missing_rows = missing_rows.merge(has_decile_elsewhere, on="School ID", how="left")

# %%
# 5) Split into two lists:
#    A) Schools that DO have a Decile somewhere (can be imputed)
#    B) Schools that NEVER have a Decile in any year (likely private/special)
can_impute = missing_rows[missing_rows["HasDecileInAnyYear"] == True]
never_had_decile = missing_rows[missing_rows["HasDecileInAnyYear"] != True]

# %%
print("🔹 Rows missing Decile but CAN be imputed from school history:")
print(can_impute[["School ID","School Name","Year","School Authority"]].drop_duplicates().head(50))
# Out:
# 🔹 Rows missing Decile but CAN be imputed from school history:
#      School ID                            School Name  Year  \
# 3          453                         Kadimah School  2010
# 7          481              City Impact Church School  2010
# 14         617  City Impact Church School (Secondary)  2010
# 15         620                         Huanui College  2010
# 19         627                        Chapman College  2010
# 22        1655                         Destiny School  2010
# 23        4101             Carncot Independent School  2010
# 30         481              City Impact Church School  2011
# 35         605                      Wentworth Primary  2011
# 36         610                      Seven Oaks School  2011
# 38         617  City Impact Church School (Secondary)  2011
# 39         620                         Huanui College  2011
# 42         627                        Chapman College  2011
# 45        1655                         Destiny School  2011
# 46        4101             Carncot Independent School  2011
# 53         481              City Impact Church School  2012
# 58         605                      Wentworth Primary  2012
# 59         610                      Seven Oaks School  2012
# 61         617  City Impact Church School (Secondary)  2012
# 62         620                         Huanui College  2012
# 65         627                        Chapman College  2012
# 69        1655                         Destiny School  2012
# 70        4101             Carncot Independent School  2012
# 77         481              City Impact Church School  2013
# 81         605                      Wentworth Primary  2013
# 82         610                      Seven Oaks School  2013
# 83         617  City Impact Church School (Secondary)  2013
# 84         620                         Huanui College  2013
# 86         627                        Chapman College  2013
# 89         682                 Eden Christian Academy  2013
# 92        1655                         Destiny School  2013
# 93        4101             Carncot Independent School  2013
# 100        481              City Impact Church School  2014
# 104        605                      Wentworth Primary  2014
# 105        610                      Seven Oaks School  2014
# 106        617  City Impact Church School (Secondary)  2014
# 107        620                         Huanui College  2014
# 109        627                        Chapman College  2014
# 112        682                 Eden Christian Academy  2014
# 113        686               Lyttelton Primary School  2014
# 123       1655                         Destiny School  2014
# 124       4101             Carncot Independent School  2014
# 126         60          Saint Kentigern Girls' School  2015
# 127         67              Diocesan School For Girls  2015
# 128        283              Otamatea Christian School  2015
# 131        436                      Springbank School  2015
# 132        441                        ACG Strathallan  2015
# 133        454                   St Dominic's College  2015
# 135        459              Immanuel Christian School  2015
# 136        460                           Atea College  2015
#
#           School Authority
# 3        State: Integrated
# 7      Private: Fully Reg.
# 14     Private: Fully Reg.
# 15     Private: Fully Reg.
# 19     Private: Fully Reg.
# 22     Private: Fully Reg.
# 23     Private: Fully Reg.
# 30     Private: Fully Reg.
# 35     Private: Fully Reg.
# 36     Private: Fully Reg.
# 38      Private: Prov.Reg.
# 39     Private: Fully Reg.
# 42     Private: Fully Reg.
# 45     Private: Fully Reg.
# 46     Private: Fully Reg.
# 53     Private: Fully Reg.
# 58     Private: Fully Reg.
# 59     Private: Fully Reg.
# 61     Private: Fully Reg.
# 62     Private: Fully Reg.
# 65     Private: Fully Reg.
# 69     Private: Fully Reg.
# 70     Private: Fully Reg.
# 77     Private: Fully Reg.
# 81     Private: Fully Reg.
# 82     Private: Fully Reg.
# 83     Private: Fully Reg.
# 84     Private: Fully Reg.
# 86     Private: Fully Reg.
# 89      Private: Prov.Reg.
# 92     Private: Fully Reg.
# 93     Private: Fully Reg.
# 100    Private: Fully Reg.
# 104    Private: Fully Reg.
# 105    Private: Fully Reg.
# 106    Private: Fully Reg.
# 107    Private: Fully Reg.
# 109    Private: Fully Reg.
# 112    Private: Fully Reg.
# 113  State: Not integrated
# 123    Private: Fully Reg.
# 124    Private: Fully Reg.
# 126    Private: Fully Reg.
# 127    Private: Fully Reg.
# 128    Private: Fully Reg.
# 131    Private: Fully Reg.
# 132    Private: Fully Reg.
# 133    Private: Fully Reg.
# 135    Private: Fully Reg.
# 136    Private: Fully Reg.

# %%
print("\n🔹 Rows missing Decile and NEVER had a Decile in any year (keep/drop):")
print(never_had_decile[["School ID","School Name","Year","School Authority"]].drop_duplicates().head(50))
# Out:
# 🔹 Rows missing Decile and NEVER had a Decile in any year (keep/drop):
#     School ID                           School Name  Year  \
# 0          52         Tyndale Park Christian School  2010
# 1         345              Pacific Christian School  2010
# 2         425       Odyssey House School (Auckland)  2010
# 4         456             Pukekohe Christian School  2010
# 5         462                    Ambury Park Centre  2010
# 6         466              Manukau Christian School  2010
# 8         486       Cambridge International College  2010
# 9         498              Te Aho o Te Kura Pounamu  2010
# 10        547                             MindAlive  2010
# 11        575    Auckland Montessori Primary School  2010
# 12        604                   Golden Grove School  2010
# 13        611          Hutt Valley Christian School  2010
# 16        621                       Destiny College  2010
# 17        622         Silverstream Christian School  2010
# 18        623                                Tu Toa  2010
# 20       1587           Gloriavale Christian School  2010
# 21       1640                    The Corelli School  2010
# 24         52         Tyndale Park Christian School  2011
# 25        345              Pacific Christian School  2011
# 26        425       Odyssey House School (Auckland)  2011
# 27        456             Pukekohe Christian School  2011
# 28        462                    Ambury Park Centre  2011
# 29        466              Manukau Christian School  2011
# 31        486       Cambridge International College  2011
# 32        498              Te Aho o Te Kura Pounamu  2011
# 33        547                             MindAlive  2011
# 34        604                   Golden Grove School  2011
# 37        611          Hutt Valley Christian School  2011
# 40        622         Silverstream Christian School  2011
# 41        626  Titirangi Rudolf Steiner High School  2011
# 43       1587           Gloriavale Christian School  2011
# 44       1640                    The Corelli School  2011
# 47         52         Tyndale Park Christian School  2012
# 48        345              Pacific Christian School  2012
# 49        425       Odyssey House School (Auckland)  2012
# 50        456             Pukekohe Christian School  2012
# 51        462                    Ambury Park Centre  2012
# 52        466              Manukau Christian School  2012
# 54        486       Cambridge International College  2012
# 55        498              Te Aho o Te Kura Pounamu  2012
# 56        547                             MindAlive  2012
# 57        604                   Golden Grove School  2012
# 60        611          Hutt Valley Christian School  2012
# 63        622         Silverstream Christian School  2012
# 64        626  Titirangi Rudolf Steiner High School  2012
# 66        656            Upper Valley Middle School  2012
# 67       1587           Gloriavale Christian School  2012
# 68       1640                    The Corelli School  2012
# 71         52         Tyndale Park Christian School  2013
# 72        345              Pacific Christian School  2013
#
#          School Authority
# 0     Private: Fully Reg.
# 1     Private: Fully Reg.
# 2     Private: Fully Reg.
# 4     Private: Fully Reg.
# 5     Private: Fully Reg.
# 6     Private: Fully Reg.
# 8     Private: Fully Reg.
# 9   State: Not integrated
# 10    Private: Fully Reg.
# 11    Private: Fully Reg.
# 12    Private: Fully Reg.
# 13    Private: Fully Reg.
# 16    Private: Fully Reg.
# 17    Private: Fully Reg.
# 18    Private: Fully Reg.
# 20    Private: Fully Reg.
# 21    Private: Fully Reg.
# 24    Private: Fully Reg.
# 25    Private: Fully Reg.
# 26    Private: Fully Reg.
# 27    Private: Fully Reg.
# 28    Private: Fully Reg.
# 29    Private: Fully Reg.
# 31    Private: Fully Reg.
# 32  State: Not integrated
# 33    Private: Fully Reg.
# 34    Private: Fully Reg.
# 37    Private: Fully Reg.
# 40    Private: Fully Reg.
# 41     Private: Prov.Reg.
# 43    Private: Fully Reg.
# 44    Private: Fully Reg.
# 47    Private: Fully Reg.
# 48    Private: Fully Reg.
# 49    Private: Fully Reg.
# 50    Private: Fully Reg.
# 51    Private: Fully Reg.
# 52    Private: Fully Reg.
# 54    Private: Fully Reg.
# 55  State: Not integrated
# 56    Private: Fully Reg.
# 57    Private: Fully Reg.
# 60    Private: Fully Reg.
# 63    Private: Fully Reg.
# 64     Private: Prov.Reg.
# 66     Private: Prov.Reg.
# 67    Private: Fully Reg.
# 68    Private: Fully Reg.
# 71    Private: Fully Reg.
# 72    Private: Fully Reg.

# %%
# 6) Impute Decile where possible (median per School ID)
df_all = df_all.sort_values(["School ID", "Year"])
df_all["Decile"] = (
    df_all
    .groupby("School ID")["Decile"]
    .transform(lambda s: s.fillna(s.median()))
)

# %%
# Check if there are still missing values
df_all.isnull().sum()
# Out:
# School ID                         0
# School Name                       0
# Year                              0
# Decile                          358
# School Type                       0
#                               ...
# Level 5                           0
# Taha Māori                        0
# None                              0
# Takiwā                        33048
# Another Gender/ Not Stated    33048
# Length: 67, dtype: int64

# %% [markdown]
# ##### **Note.**
# All 358 records in "Decile" column that contain missing values are private, special, or newly established schools that were not assigned a decile. They will be omitted since they are irrelevant to the analysis.

# %%
# Delete the 358 schools without a decile
df_all = df_all.dropna(subset=["Decile"])

# %%
df_all.shape
# Out:
# (37761, 67)

# %% [markdown]
# #### Check for outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df_all['Total Roll'])
plt.title('Outlier Detection with Boxplot--Roll')
plt.show()

# %%
sns.boxplot(x=df_all['Māori'])
plt.title('Outlier Detection with Boxplot_Māori')
plt.show()

# %%
sns.boxplot(x=df_all['Level 1'])
plt.title('Outlier Detection with Boxplot_Level1')
plt.show()

# %% [markdown]
# **Observation**
# There are outliers in "Decile", "Māori", "Level 1". However, removing these outliers would risk information loss and reduce the representativeness of the dataset. Instead, their impact will be considered during interpretation and visualized appropriately (e.g., via boxplots or log scaling if needed).

# %% [markdown]
# #### **Step 4** Delete the irrelevant columns

# %%
# --- Inspect the columns of the merged dataset ---
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37761 entries, 0 to 38118
# Data columns (total 67 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   School ID                     37761 non-null  int64
#  1   School Name                   37761 non-null  object
#  2   Year                          37761 non-null  int64
#  3   Decile                        37761 non-null  float64
#  4   School Type                   37761 non-null  object
#  5   School Authority              37761 non-null  object
#  6   School Gender                 37761 non-null  object
#  7   Regional Council              37761 non-null  object
#  8   Education Region              37761 non-null  object
#  9   TA with Auckland Local Board  37761 non-null  object
#  10  Total Roll                    37761 non-null  int64
#  11  Female                        37761 non-null  object
#  12  Male                          37761 non-null  object
#  13  Māori                         37761 non-null  int64
#  14  Pacific                       37761 non-null  int64
#  15  Asian                         37761 non-null  int64
#  16  MELAA                         37761 non-null  int64
#  17  Other                         37761 non-null  int64
#  18  European/ Pākehā              37761 non-null  int64
#  19  International Fee Paying      37761 non-null  int64
#  20  All Funded                    37761 non-null  int64
#  21  Alternative Education         37761 non-null  int64
#  22  International Fee Paying.1    37761 non-null  int64
#  23  Secondary-Tertiary Programme  37761 non-null  int64
#  24  Year 1                        37761 non-null  int64
#  25  Year 2                        37761 non-null  int64
#  26  Year 3                        37761 non-null  int64
#  27  Year 4                        37761 non-null  int64
#  28  Year 5                        37761 non-null  int64
#  29  Year 6                        37761 non-null  int64
#  30  Year 7                        37761 non-null  int64
#  31  Year 8                        37761 non-null  int64
#  32  Year 9                        37761 non-null  int64
#  33  Year 10                       37761 non-null  int64
#  34  Year 11                       37761 non-null  int64
#  35  Year 12                       37761 non-null  int64
#  36  Year 13                       37761 non-null  int64
#  37  Year 14                       37761 non-null  int64
#  38  Year 15                       37761 non-null  int64
#  39  Age 5                         37761 non-null  object
#  40  Age 6                         37761 non-null  object
#  41  Age 7                         37761 non-null  object
#  42  Age 8                         37761 non-null  object
#  43  Age 9                         37761 non-null  object
#  44  Age 10                        37761 non-null  object
#  45  Age 11                        37761 non-null  object
#  46  Age 12                        37761 non-null  object
#  47  Age 13                        37761 non-null  object
#  48  Age 14                        37761 non-null  object
#  49  Age 15                        37761 non-null  object
#  50  Age 16                        37761 non-null  object
#  51  Age 17                        37761 non-null  object
#  52  Age 18                        37761 non-null  object
#  53  Age 19                        37761 non-null  object
#  54  Age 20                        37761 non-null  object
#  55  Age 21                        37761 non-null  object
#  56  Age 22+                       37761 non-null  object
#  57  Level 1                       37761 non-null  int64
#  58  Level 2                       37761 non-null  int64
#  59  Level 3                       37761 non-null  int64
#  60  Level 4A                      37761 non-null  int64
#  61  Level 4B                      37761 non-null  int64
#  62  Level 5                       37761 non-null  int64
#  63  Taha Māori                    37761 non-null  int64
#  64  None                          37761 non-null  int64
#  65  Takiwā                        5007 non-null   object
#  66  Another Gender/ Not Stated    5007 non-null   object
# dtypes: float64(1), int64(37), object(29)
# memory usage: 19.6+ MB

# %%
# --- Check the columns to be deleted ---
df_all.columns[[8, 9, 11, 12, 65, 66]]
# Out:
# Index(['Education Region', 'TA with Auckland Local Board', 'Female', 'Male',
#        'Takiwā', 'Another Gender/ Not Stated'],
#       dtype='object')

# %%
df_all.columns[24:57]
# Out:
# Index(['Year 1', 'Year 2', 'Year 3', 'Year 4', 'Year 5', 'Year 6', 'Year 7',
#        'Year 8', 'Year 9', 'Year 10', 'Year 11', 'Year 12', 'Year 13',
#        'Year 14', 'Year 15', 'Age 5', 'Age 6', 'Age 7', 'Age 8', 'Age 9',
#        'Age 10', 'Age 11', 'Age 12', 'Age 13', 'Age 14', 'Age 15', 'Age 16',
#        'Age 17', 'Age 18', 'Age 19', 'Age 20', 'Age 21', 'Age 22+'],
#       dtype='object')

# %%
# --- Delete the unhelpful columns ---
cols_to_drop = list(df_all.columns[[8, 9, 11, 12, 65, 66]]) + list(df_all.columns[24:57])
df_all = df_all.drop(columns=cols_to_drop)

# %%
# --- Confirm the deletion ---
df_all.head()
# Out:
#        School ID       School Name  Year  Decile   School Type  \
# 0              1  Te Kura o Te Kao  2010     2.0  Full Primary
# 2577           1  Te Kura o Te Kao  2011     2.0  Full Primary
# 5145           1  Te Kura o Te Kao  2012     2.0  Full Primary
# 7703           1  Te Kura o Te Kao  2013     2.0  Full Primary
# 10241          1  Te Kura o Te Kao  2014     2.0  Full Primary
#
#             School Authority School Gender  Regional Council  Total Roll  \
# 0      State: Not integrated         Co-Ed  Northland Region          27
# 2577   State: Not integrated         Co-Ed  Northland Region          30
# 5145   State: Not integrated         Co-Ed  Northland Region          26
# 7703   State: Not integrated         Co-Ed  Northland Region          31
# 10241  State: Not integrated         Co-Ed  Northland Region          32
#
#        Māori  ...  International Fee Paying.1  Secondary-Tertiary Programme  \
# 0         27  ...                           0                             0
# 2577      30  ...                           0                             0
# 5145      26  ...                           0                             0
# 7703      31  ...                           0                             0
# 10241     32  ...                           0                             0
#
#        Level 1  Level 2  Level 3  Level 4A  Level 4B  Level 5  Taha Māori  \
# 0            0        0        0        10        17        0           0
# 2577         0        0        0        30         0        0           0
# 5145         0        0       26         0         0        0           0
# 7703         0        0       31         0         0        0           0
# 10241       14       18        0         0         0        0           0
#
#        None
# 0         0
# 2577      0
# 5145      0
# 7703      0
# 10241     0
#
# [5 rows x 28 columns]

# %% [markdown]
# #### **Step 3** Check the duplicates and mix datatypes

# %%
# Find duplicates for df_all.csv
df_dups = df_all[df_all.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [School ID, School Name, Year, Decile, School Type, School Authority, School Gender, Regional Council, Total Roll, Māori, Pacific, Asian, MELAA, Other, European/ Pākehā, International Fee Paying, All Funded, Alternative Education, International Fee Paying.1, Secondary-Tertiary Programme, Level 1, Level 2, Level 3, Level 4A, Level 4B, Level 5, Taha Māori, None]
# Index: []
#
# [0 rows x 28 columns]

# %%
# Find columns that contain mixed datatypes
for col in df_all.columns.tolist():
  weird = (df_all[[col]].map(type) != df_all[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_all[weird]) > 0:
    print (col)

# %% [markdown]
# **Observation:** No duplicates or mix datatypes are found.

# %%
df_all.describe()
# Out:
#           School ID          Year        Decile    Total Roll         Māori  \
# count  37761.000000  37761.000000  37761.000000  37761.000000  37761.000000
# mean    2041.724795   2016.976696      5.460263    313.193665     74.464500
# std     1284.704557      4.328284      2.936712    348.899495     86.145113
# min        1.000000   2010.000000      1.000000      0.000000      0.000000
# 25%     1194.000000   2013.000000      3.000000     91.000000     18.000000
# 50%     1927.000000   2017.000000      5.000000    209.000000     45.000000
# 75%     2966.000000   2021.000000      8.000000    413.000000     98.000000
# max     6980.000000   2024.000000     10.000000   3775.000000    879.000000
#
#             Pacific         Asian         MELAA         Other  \
# count  37761.000000  37761.000000  37761.000000  37761.000000
# mean      30.887159     39.784963      6.376685      2.837875
# std       80.414360     95.563005     13.027208     10.087351
# min        0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      1.000000      0.000000      0.000000
# 50%        6.000000      8.000000      1.000000      0.000000
# 75%       23.000000     34.000000      7.000000      2.000000
# max     1316.000000   1781.000000    223.000000    697.000000
#
#        European/ Pākehā  ...  International Fee Paying.1  \
# count      37761.000000  ...                37761.000000
# mean         155.185191  ...                    3.657318
# std          206.643582  ...                   17.721445
# min            0.000000  ...                    0.000000
# 25%           23.000000  ...                    0.000000
# 50%           84.000000  ...                    0.000000
# 75%          208.000000  ...                    0.000000
# max         1695.000000  ...                  690.000000
#
#        Secondary-Tertiary Programme       Level 1       Level 2       Level 3  \
# count                  37761.000000  37761.000000  37761.000000  37761.000000
# mean                       2.094807      5.854983      2.194010      3.130584
# std                       10.856763     26.818717     12.584648     19.439933
# min                        0.000000      0.000000      0.000000      0.000000
# 25%                        0.000000      0.000000      0.000000      0.000000
# 50%                        0.000000      0.000000      0.000000      0.000000
# 75%                        0.000000      0.000000      0.000000      0.000000
# max                      381.000000    461.000000    240.000000    631.000000
#
#           Level 4A      Level 4B       Level 5    Taha Māori          None
# count  37761.00000  37761.000000  37761.000000  37761.000000  37761.000000
# mean       3.91899     12.801462     49.742592    133.323588     95.936336
# std       27.66678     50.483568    118.324656    187.024999    301.867787
# min        0.00000      0.000000      0.000000      0.000000    -19.000000
# 25%        0.00000      0.000000      0.000000      0.000000      0.000000
# 50%        0.00000      0.000000      0.000000     40.000000      0.000000
# 75%        0.00000      0.000000     26.000000    213.000000      0.000000
# max      625.00000    773.000000   1113.000000   1561.000000   3345.000000
#
# [8 rows x 23 columns]

# %%
df_all.head()
# Out:
#        School ID       School Name  Year  Decile   School Type  \
# 0              1  Te Kura o Te Kao  2010     2.0  Full Primary
# 2577           1  Te Kura o Te Kao  2011     2.0  Full Primary
# 5145           1  Te Kura o Te Kao  2012     2.0  Full Primary
# 7703           1  Te Kura o Te Kao  2013     2.0  Full Primary
# 10241          1  Te Kura o Te Kao  2014     2.0  Full Primary
#
#             School Authority School Gender  Regional Council  Total Roll  \
# 0      State: Not integrated         Co-Ed  Northland Region          27
# 2577   State: Not integrated         Co-Ed  Northland Region          30
# 5145   State: Not integrated         Co-Ed  Northland Region          26
# 7703   State: Not integrated         Co-Ed  Northland Region          31
# 10241  State: Not integrated         Co-Ed  Northland Region          32
#
#        Māori  ...  International Fee Paying.1  Secondary-Tertiary Programme  \
# 0         27  ...                           0                             0
# 2577      30  ...                           0                             0
# 5145      26  ...                           0                             0
# 7703      31  ...                           0                             0
# 10241     32  ...                           0                             0
#
#        Level 1  Level 2  Level 3  Level 4A  Level 4B  Level 5  Taha Māori  \
# 0            0        0        0        10        17        0           0
# 2577         0        0        0        30         0        0           0
# 5145         0        0       26         0         0        0           0
# 7703         0        0       31         0         0        0           0
# 10241       14       18        0         0         0        0           0
#
#        None
# 0         0
# 2577      0
# 5145      0
# 7703      0
# 10241     0
#
# [5 rows x 28 columns]

# %%
# --- Save the merged dataset ---
output_path = r"C:\Users\sanch\Documents\CareerFoundry\Achievement 6\1. Data\Merged_Student_Rolls.csv"
df_all.to_csv(output_path, index=False, encoding='utf-8-sig')
